# %%
import scanpy as sc

# %%
a=sc.read_h5ad("E:/RNA_seq/s_fca_biohub_head_10x.h5ad")

# %%
a.X
# Out:
# array([[-0.40631983, -1.5331094 , -0.6076581 , ...,  1.3241693 ,
#          0.08683938, -0.01641489],
#        [-0.16298832, -0.6248119 , -0.45903865, ..., -0.61279655,
#         -0.11221627, -0.11894714],
#        [-0.2586045 , -0.6904109 , -0.50186324, ...,  0.511944  ,
#         -0.25782126, -0.1269794 ],
#        ...,
#        [-0.11645231, -0.4423011 , -0.4301452 , ..., -0.4896773 ,
#          4.4999194 , -0.1400162 ],
#        [-0.24738836, -0.7007565 ,  1.2267499 , ..., -0.71157485,
#         -0.2268803 , -0.1230447 ],
#        [-0.1508685 , -0.40116122, -0.44209763, ...,  1.7238438 ,
#          5.0915804 , -0.1536481 ]], dtype=float32)

# %%
a.obs
# Out:
#                                                     age batch  batch_id  \
# index
# AAACCCAGTTACGGAG-d541ae4e__FCA1_MaleFemale_Head       5     0         1
# AAACCCATCCGTACGG-d541ae4e__FCA1_MaleFemale_Head       5     0         1
# AAACGAAGTATGATCC-d541ae4e__FCA1_MaleFemale_Head       5     0         1
# AAACGAATCACCTACC-d541ae4e__FCA1_MaleFemale_Head       5     0         1
# AAACGCTAGAAACCAT-d541ae4e__FCA1_MaleFemale_Head       5     0         1
# ...                                                 ...   ...       ...
# TTTGGTTGTACGAAAT-f7ed0992__FCA15_Female_head_adult    5    12         2
# TTTGTTGCAACGCATT-f7ed0992__FCA15_Female_head_adult    5    12         2
# TTTGTTGTCATCGCCT-f7ed0992__FCA15_Female_head_adult    5    12         2
# TTTGTTGTCCATTCGC-f7ed0992__FCA15_Female_head_adult    5    12         2
# TTTGTTGTCGCTTGCT-f7ed0992__FCA15_Female_head_adult    5    12         2
#
#                                                     celda_decontx__clusters  \
# index
# ...

# %%
a.var
# Out:
#                               ID               Symbol             Type  \
# index
# 28SrRNA-Psi:CR40596  FBgn0085753  28SrRNA-Psi:CR40596  Gene Expression
# 5-HT1A               FBgn0004168               5-HT1A  Gene Expression
# 5-HT2A               FBgn0087012               5-HT2A  Gene Expression
# AANAT1               FBgn0019643               AANAT1  Gene Expression
# AANATL2              FBgn0031791              AANATL2  Gene Expression
# ...                          ...                  ...              ...
# yip2                 FBgn0040064                 yip2  Gene Expression
# zfh1                 FBgn0004606                 zfh1  Gene Expression
# zfh2                 FBgn0004607                 zfh2  Gene Expression
# zormin               FBgn0052311               zormin  Gene Expression
# zyd                  FBgn0265767                  zyd  Gene Expression
#
#                      n_cells  highly_variable     means  dispersions  \
# index
# ...

# %%
a.uns
# Out:
# {'leiden_res0.4__harmony': {'computed': array([ True]),
#   'location': array(["AnnData.obsm['X_pca']"], dtype=object)},
#  'leiden_res0.4__leiden': {'params': {'n_iterations': array([-1], dtype=int64),
#    'random_state': array([190], dtype=int64),
#    'resolution': array([0.4])}},
#  'leiden_res0.4__neighbors': {'connectivities': <100527x100527 sparse matrix of type '<class 'numpy.float64'>'
#   	with 2448362 stored elements in Compressed Sparse Row format>,
#   'distances': <100527x100527 sparse matrix of type '<class 'numpy.float64'>'
#   	with 1407378 stored elements in Compressed Sparse Row format>,
#   'params': {'method': array(['umap'], dtype=object),
#    'metric': array(['euclidean'], dtype=object),
#    'n_neighbors': array([15], dtype=int64),
#    'n_pcs': array([61], dtype=int64)}},
#  'leiden_res0.4__pca': {'variance': array([52.85233671, 19.73950396, 16.17542601, 13.96478274, 12.21702097,
#           8.6696433 ,  7.79131207,  7.72667954,  6.82399267,  6.50440122,
# ...

# %% [markdown]
# 可以看出来分析的结果应该都存在这个unstructured annotation里面

# %%
a.obs_names
# Out:
# Index(['AAACCCAGTTACGGAG-d541ae4e__FCA1_MaleFemale_Head',
#        'AAACCCATCCGTACGG-d541ae4e__FCA1_MaleFemale_Head',
#        'AAACGAAGTATGATCC-d541ae4e__FCA1_MaleFemale_Head',
#        'AAACGAATCACCTACC-d541ae4e__FCA1_MaleFemale_Head',
#        'AAACGCTAGAAACCAT-d541ae4e__FCA1_MaleFemale_Head',
#        'AAACGCTAGCAATAGT-d541ae4e__FCA1_MaleFemale_Head',
#        'AAACGCTCAACTTCTT-d541ae4e__FCA1_MaleFemale_Head',
#        'AAACGCTTCAGACCTA-d541ae4e__FCA1_MaleFemale_Head',
#        'AAAGAACAGCAACTCT-d541ae4e__FCA1_MaleFemale_Head',
#        'AAAGAACCACTTGTGA-d541ae4e__FCA1_MaleFemale_Head',
#        ...
#        'TTTGGTTAGTAATTGG-f7ed0992__FCA15_Female_head_adult',
#        'TTTGGTTAGTCCTACA-f7ed0992__FCA15_Female_head_adult',
#        'TTTGGTTCACATACTG-f7ed0992__FCA15_Female_head_adult',
#        'TTTGGTTCATCGGTTA-f7ed0992__FCA15_Female_head_adult',
#        'TTTGGTTCATTGACCA-f7ed0992__FCA15_Female_head_adult',
#        'TTTGGTTGTACGAAAT-f7ed0992__FCA15_Female_head_adult',
# ...

# %%
a.var_names#这1838个基因代表的是什么?
# Out:
# Index(['28SrRNA-Psi:CR40596', '5-HT1A', '5-HT2A', 'AANAT1', 'AANATL2', 'ACXD',
#        'AGO3', 'AOX1', 'AOX3', 'AOX4',
#        ...
#        'yellow-d', 'yellow-e', 'yellow-f2', 'yellow-h', 'yin', 'yip2', 'zfh1',
#        'zfh2', 'zormin', 'zyd'],
#       dtype='object', name='index', length=1838)

# %%
a.n_obs
# Out:
# 100527

# %%
a.n_vars
# Out:
# 1838
